# %%
#list
my_list = [1,2,5,7,5,'apple']
my_set = {1,2,4,5,4,'apple', 'apple'}
my_tuple = (1,2,4,5,4,'apple', 'apple')
my_dict = {1:4,2:5,4:8,1:2,'fruit': 'apple', 'fruit': 'grapes'

}
def printAll():
    print(f"list:{my_list}")
    print(f"set: {my_set}")
    print(f"tuple: {my_tuple}")
    print(f"dictionary: {my_dict}")
    #print(my_dict)
printAll()
# Out:
# list:[1, 2, 5, 7, 5, 'apple']
# set: {1, 2, 4, 5, 'apple'}
# tuple: (1, 2, 4, 5, 4, 'apple', 'apple')
# dictionary: {1: 2, 2: 5, 4: 8, 'fruit': 'grapes'}

# %%
#Various Operations
my_list.append(1)
my_set.add(10)
my_set.add(5)
my_dict['animal'] = 'cat'
printAll()
# Out:
# list:[1, 2, 5, 7, 5, 'apple', 1]
# set: {1, 2, 4, 5, 'apple', 10}
# tuple: (1, 2, 4, 5, 4, 'apple', 'apple')
# dictionary: {1: 2, 2: 5, 4: 8, 'fruit': 'grapes', 'animal': 'cat'}

# %%
my_list[1] = True
print(len(my_list))
print(len(my_set))
print(len(my_tuple))
print(len(my_dict))
printAll()
# Out:
# 7
# 6
# 7
# 5
# list:[1, True, 5, 7, 5, 'apple', 1]
# set: {1, 2, 4, 5, 'apple', 10}
# tuple: (1, 2, 4, 5, 4, 'apple', 'apple')
# dictionary: {1: 2, 2: 5, 4: 8, 'fruit': 'grapes', 'animal': 'cat'}

# %%
my_set2 = set(my_list)
my_tuple2 = tuple(my_list)
my_list2 = list(my_set)
print(my_set2)
print(my_tuple2)
print(my_list2)
# Out:
# {1, 5, 'apple', 7}
# (1, True, 5, 7, 5, 'apple', 1)
# [1, 2, 4, 5, 'apple', 10]
